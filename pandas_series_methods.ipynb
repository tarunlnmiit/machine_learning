# %% [markdown]
# # Pandas.Series Methods

# %%
import pandas as pd

# %% [markdown]
# ## Examples to be used

# %%
songs_66 = pd.Series([3, None , 11, 9],
    index=['George', 'Ringo', 'John', 'Paul'],
    name='Counts')
songs_66
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
songs_69 = pd.Series([18, 22, 7, 5],
    index=[ 'John', 'Paul', 'George', 'Ringo'],
    name='Counts')

songs_69
# Out:
# John      18
# Paul      22
# George     7
# Ringo      5
# Name: Counts, dtype: int64

# %% [markdown]
# ## Iteration over a pandas series

# %% [markdown]
# ### Option 1

# %%
for value in songs_66:
    print(value)
# Out:
# 3.0
# nan
# 11.0
# 9.0

# %% [markdown]
# ### Option 2

# %%
for idx, value in songs_66.iteritems():
    print(idx, value)
# Out:
# George 3.0
# Ringo nan
# John 11.0
# Paul 9.0

# %% [markdown]
# ### Option 3

# %%
for key in songs_66.keys():
    print(key)
# Out:
# George
# Ringo
# John
# Paul

# %% [markdown]
# # Overloaded Operations
#
# ## Operation, Result (All return Series)
# * +, Adds scalar
# * -, Subtracts scalar
# * /, Divides scalar
# * //, Floor divides scalar
# * *, Multiply scalar
# * %, Modulus scalar
# * == / !=, Equality scalar
# * < / >, Greater / less than scalar
# * <= / >=, Greater / less than or equal scalar
# * ^, Binary XOR
# * |, Binary OR
# * &, Binary AND

# %% [markdown]
# #### Arithmetic Operations

# %%
songs_66 + 2
# Out:
# George     5.0
# Ringo      NaN
# John      13.0
# Paul      11.0
# Name: Counts, dtype: float64

# %%
[1, 2] * 3
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
print(songs_66 + songs_69)
print(songs_66)
print(songs_69)
# Out:
# George    10.0
# John      29.0
# Paul      31.0
# Ringo      NaN
# Name: Counts, dtype: float64
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64
# John      18
# Paul      22
# George     7
# Ringo      5
# Name: Counts, dtype: int64

# %%
songs_66.fillna(0) + songs_69
# Out:
# George    10.0
# John      29.0
# Paul      31.0
# Ringo      5.0
# Name: Counts, dtype: float64

# %% [markdown]
# #### Comparison Operations

# %%
print(songs_66.fillna(0).sort_index())
print(songs_69.fillna(0).sort_index())
songs_66.fillna(0).sort_index() <= songs_69.fillna(0).sort_index()
# Out:
# George     3.0
# John      11.0
# Paul       9.0
# Ringo      0.0
# Name: Counts, dtype: float64
# George     7
# John      18
# Paul      22
# Ringo      5
# Name: Counts, dtype: int64
# George    True
# John      True
# Paul      True
# Ringo     True
# Name: Counts, dtype: bool

# %% [markdown]
# ## Getting and Setting Values

# %% [markdown]
# ### Getting Values

# %%
songs_66['John']
# Out:
# 11.0

# %%
songs_66.get('Fred', 'missing')
# Out:
# 'missing'

# %%
songs_66.John
# dotted attribute access supported only for valid attribute names and no conflicts with pre-existing series attributes
# Out:
# 11.0

# %% [markdown]
# ### Setting Values

# %%
songs_66['John'] = 81
songs_66
# Out:
# George     3.0
# Ringo      NaN
# John      81.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
songs_66.John = 81
songs_66['John']
# Out:
# 81.0

# %% [markdown]
# ## Resetting Index

# %%
print(songs_66)
songs_66.reset_index()
# Out:
# George     3.0
# Ringo      NaN
# John      81.0
# Paul       9.0
# Name: Counts, dtype: float64
#     index  Counts
# 0  George     3.0
# 1   Ringo     NaN
# 2    John    81.0
# 3    Paul     9.0

# %%
songs_66.reset_index(drop=True)
# Out:
# 0     3.0
# 1     NaN
# 2    81.0
# 3     9.0
# Name: Counts, dtype: float64

# %%
songs_66.reindex(['Billy', 'Eric', 'George', 'Yoko'], fill_value=-1)
# Out:
# Billy    -1.0
# Eric     -1.0
# George    3.0
# Yoko     -1.0
# Name: Counts, dtype: float64

# %%
songs_66.rename({'Ringo':'Richard'})
# Out:
# George      3.0
# Richard     NaN
# John       81.0
# Paul        9.0
# Name: Counts, dtype: float64

# %%
songs_66.rename(lambda x: x.lower())
# Out:
# george     3.0
# ringo      NaN
# john      81.0
# paul       9.0
# Name: Counts, dtype: float64

# %% [markdown]
# ## Counting

# %%
songs_66 = pd.Series([3, None , 11, 9],
    index=['George', 'Ringo', 'John', 'Paul'],
    name='Counts')
songs_66
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
scores_2 = pd.Series([67.3, 100, 96.7, None, 100],
    index=['Ringo', 'Paul', 'George', 'Peter', 'Billy'],
    name='test2')
scores_2
# Out:
# Ringo      67.3
# Paul      100.0
# George     96.7
# Peter       NaN
# Billy     100.0
# Name: test2, dtype: float64

# %%
scores_2.count()
# Out:
# 4

# %%
scores_2.value_counts()
# Out:
# 100.0    2
# 96.7     1
# 67.3     1
# Name: test2, dtype: int64

# %%
scores_2.unique()
# Out:
# array([ 67.3, 100. ,  96.7,   nan])

# %%
scores_2.nunique()
# Out:
# 3

# %%
scores_2.drop_duplicates()
# Out:
# Ringo      67.3
# Paul      100.0
# George     96.7
# Peter       NaN
# Name: test2, dtype: float64

# %%
scores_2.duplicated()
# Out:
# Ringo     False
# Paul      False
# George    False
# Peter     False
# Billy      True
# Name: test2, dtype: bool

# %%
scores_3 = pd.Series([67.3, 100, 96.7, None, 100, 79],
    index=['Ringo', 'Paul', 'George', 'Peter', 'Billy', 'Paul'])
scores_3
# Out:
# Ringo      67.3
# Paul      100.0
# George     96.7
# Peter       NaN
# Billy     100.0
# Paul       79.0
# dtype: float64

# %%
scores_3.groupby(scores_3.index).first()
# Out:
# Billy     100.0
# George     96.7
# Paul      100.0
# Peter       NaN
# Ringo      67.3
# dtype: float64

# %%
scores_3.groupby(scores_3.index).last()
# Out:
# Billy     100.0
# George     96.7
# Paul       79.0
# Peter       NaN
# Ringo      67.3
# dtype: float64

# %% [markdown]
# ## Statistics

# %%
print(songs_66)
songs_66.sum()
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64
# 23.0

# %%
songs_66.sum(skipna=False)
# Out:
# nan

# %%
songs_66.mean()
# Out:
# 7.666666666666667

# %%
songs_66.median()
# Out:
# 9.0

# %%
songs_66.quantile() # 50% value the default
# Out:
# 9.0

# %%
songs_66.quantile(.1) # 10th percentile
# Out:
# 4.2

# %%
songs_66.quantile(.9) # 90th percentile
# Out:
# 10.6

# %%
songs_66.describe()
# Out:
# count     3.000000
# mean      7.666667
# std       4.163332
# min       3.000000
# 25%       6.000000
# 50%       9.000000
# 75%      10.000000
# max      11.000000
# Name: Counts, dtype: float64

# %%
songs_66.describe(percentiles=[.05, .1, .2])
# Out:
# count     3.000000
# mean      7.666667
# std       4.163332
# min       3.000000
# 5%        3.600000
# 10%       4.200000
# 20%       5.400000
# 50%       9.000000
# max      11.000000
# Name: Counts, dtype: float64

# %%
songs_66.min()
# Out:
# 3.0

# %%
songs_66.max()
# Out:
# 11.0

# %%
songs_66.idxmin()
# Out:
# 'George'

# %%
songs_66.idxmax()
# Out:
# 'John'

# %%
songs_66.var()
# Out:
# 17.333333333333336

# %%
songs_66.std()
# Out:
# 4.163331998932266

# %%
songs_66.mad()
# Out:
# 3.1111111111111107

# %% [markdown]
# ## Converting Types

# %%
songs_66.round()
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
songs_66.astype(str)
# Out:
# George     3.0
# Ringo      nan
# John      11.0
# Paul       9.0
# Name: Counts, dtype: object

# %%
songs_66.astype(str).max()
# Out:
# 'nan'

# %%
pd.to_numeric(songs_66.apply(str))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "nan"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-fcdc02716d96> in <module>
# ----> 1 pd.to_numeric(songs_66.apply(str))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "nan" at position 1

# %% [markdown]
# ## Dealing with Null Values

# %%
songs_66.fillna(-1)
# Out:
# George     3.0
# Ringo     -1.0
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
songs_66.dropna()
# Out:
# George     3.0
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
val_mask = songs_66.notnull()
val_mask
# Out:
# George     True
# Ringo     False
# John       True
# Paul       True
# Name: Counts, dtype: bool

# %%
songs_66[val_mask]
# Out:
# George     3.0
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
nan_mask = songs_66.isnull()
nan_mask
# Out:
# George    False
# Ringo      True
# John      False
# Paul      False
# Name: Counts, dtype: bool

# %%
songs_66[nan_mask]
# Out:
# Ringo   NaN
# Name: Counts, dtype: float64

# %%
val_mask = ~(nan_mask)
songs_66[val_mask]
# Out:
# George     3.0
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %% [markdown]
# ## Matrix Operations

# %%
print(songs_66)
print(songs_69)
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64
# John      18
# Paul      22
# George     7
# Ringo      5
# Name: Counts, dtype: int64

# %%
songs_66.dot(songs_69)
# Out:
# nan

# %%
songs_66.dropna().dot(songs_66.dropna())
# Out:
# 211.0

# %%
songs_66.T
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %%
songs_66.transpose()
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# Name: Counts, dtype: float64

# %% [markdown]
# ## Append, combining, and joining two series

# %%
songs_66.append(songs_69)
# Out:
# George     3.0
# Ringo      NaN
# John      11.0
# Paul       9.0
# John      18.0
# Paul      22.0
# George     7.0
# Ringo      5.0
# Name: Counts, dtype: float64

# %%
songs_66.append(songs_69, verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-78d043d89999> in <module>
# ----> 1 songs_66.append(songs_69, verify_integrity=True)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/series.py in append(self, to_append, ignore_index, verify_integrity)
#    2692             msg = "to_append should be a Series or list/tuple of Series, got DataFrame"
#    2693             raise TypeError(msg)
# -> 2694         return concat(
#    2695             to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    2696         )
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     465         self.copy = copy
#     466
# --> 467         self.new_axes = self._get_new_axes()
#     468
#     469     def get_result(self):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     535     def _get_new_axes(self) -> List[Index]:
#     536         ndim = self._get_result_dim()
# --> 537         return [
#     538             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
#     539             for i in range(ndim)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     536         ndim = self._get_result_dim()
#     537         return [
# --> 538             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
#     539             for i in range(ndim)
#     540         ]
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     596             )
#     597
# --> 598         self._maybe_check_integrity(concat_axis)
#     599
#     600         return concat_axis
#
# /opt/homebrew/Caskroom/miniforge/base/envs/bot_env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _maybe_check_integrity(self, concat_index)
#     604             if not concat_index.is_unique:
#     605                 overlap = concat_index[concat_index.duplicated()].unique()
# --> 606                 raise ValueError(f"Indexes have overlapping values: {overlap}")
#     607
#     608
#
# ValueError: Indexes have overlapping values: Index(['John', 'Paul', 'George', 'Ringo'], dtype='object')

# %%
def avg(v1, v2):
    return (v1 + v2) / 2.0
songs_66.combine(songs_69, avg)
# Out:
# George     5.0
# John      14.5
# Paul      15.5
# Ringo      NaN
# Name: Counts, dtype: float64

# %%
songs_66.update(songs_69)
songs_66
# Out:
# George     7.0
# Ringo      5.0
# John      18.0
# Paul      22.0
# Name: Counts, dtype: float64

# %%
songs_69.repeat(3)
# Out:
# John      18
# John      18
# John      18
# Paul      22
# Paul      22
# Paul      22
# George     7
# George     7
# George     7
# Ringo      5
# Ringo      5
# Ringo      5
# Name: Counts, dtype: int64

# %% [markdown]
# ## Sorting

# %%
songs_66.sort_values()
# Out:
# Ringo      5.0
# George     7.0
# John      18.0
# Paul      22.0
# Name: Counts, dtype: float64

# %%
songs_66.sort_values(ascending=False)
# Out:
# Paul      22.0
# John      18.0
# George     7.0
# Ringo      5.0
# Name: Counts, dtype: float64

# %%
songs_66.sort_index()
# Out:
# George     7.0
# John      18.0
# Paul      22.0
# Ringo      5.0
# Name: Counts, dtype: float64

# %%
songs_66.sort_index(ascending=False)
# Out:
# Ringo      5.0
# Paul      22.0
# John      18.0
# George     7.0
# Name: Counts, dtype: float64

# %%
songs_66.rank()
# Out:
# George    2.0
# Ringo     1.0
# John      3.0
# Paul      4.0
# Name: Counts, dtype: float64

# %% [markdown]
# ## Applying a function

# %%
def format(x):
    if x == 1:
        template = '{} song'
    else:
        template = '{} songs'
    return template.format(x)
songs_66.map(format) # function as a parameters
# Out:
# George     7.0 songs
# Ringo      5.0 songs
# John      18.0 songs
# Paul      22.0 songs
# Name: Counts, dtype: object

# %%
songs_66.apply(lambda x: x + 1)
# Out:
# George     8.0
# Ringo      6.0
# John      19.0
# Paul      23.0
# Name: Counts, dtype: float64

# %%
songs_66.map({5: None,
              18: 21,
              22: 23}) # dictionary as a parameter
# Out:
# George     NaN
# Ringo      NaN
# John      21.0
# Paul      23.0
# Name: Counts, dtype: float64

# %%
mapping = pd.Series({22.: 33})
songs_66.map(mapping) # series as a parameter
# Out:
# George     NaN
# Ringo      NaN
# John       NaN
# Paul      33.0
# Name: Counts, dtype: float64

# %% [markdown]
# ## String Operations

# %%
names = pd.Series(['George', 'John', 'Paul'])
names.str.lower()
# Out:
# 0    george
# 1      john
# 2      paul
# dtype: object

# %%
names.str.findall('o')
# Out:
# 0    [o]
# 1    [o]
# 2     []
# dtype: object

# %% [markdown]
# # Vectorized String Methods similar to python applicable on pandas series
#
# ## Method, Result
# * contains, pattern matching boolean result
# * count, pattern occurrence count result
# * decode, decode a codec encoding
# * encode, encode a codec encoding
# * startswith, pattern matching for string start with boolean result
# * endswith, pattern matching for string end with boolean result
# * findall, find pattern in string
# * get, attribute access on items
# * join, join items with a separator into a string
# * len, total size of items
# * lower, convert items to lowercase
# * upper, convert items to uppercase
# * lstrip, removes whitespaces to the left of items
# * rstrip, removes whitespaces to the right of items
# * strip, removes whitespaces to both sides of items
# * repeat, repeat the string a certain number of times
# * replace, change/replace a particular part of string
# * slice, pull slices of string
# * split, split items by pattern
# * title, titlecase the items

# %%
names
# Out:
# 0    George
# 1      John
# 2      Paul
# dtype: object

# %%
names.str.len()
# Out:
# 0    6
# 1    4
# 2    4
# dtype: int64

# %%
names.str.upper()
# Out:
# 0    GEORGE
# 1      JOHN
# 2      PAUL
# dtype: object
